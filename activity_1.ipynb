# %% [markdown]
# # Activity 1

# %%
from PIL import Image #importing the Image function to read images
import matplotlib.pyplot as plt #import matplotlib for plotting of images
import os #import os to access images in the folder/file
import numpy as np
import pandas as pd
from simple_colors import *

# %%
path = 'data' #all images are in the folder named data
im = os.listdir(path) #accessing the images in folder
print(blue('Loading all 165 images',['bold', 'reverse']))
for img in im:
    x = Image.open(os.path.join(path,img))
    print('title:' + '\t' + str(img) + '\t'+ '\t' + str(x))
# Out:
# Loading all 165 images
# title:	subject01.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject01.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C8A1D60>
# title:	subject01.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject01.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject01.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x213397B9B50>
# title:	subject01.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject01.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject01.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject01.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject01.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject01.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject02.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject02.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject02.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject02.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject02.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x21339737E20>
# title:	subject02.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject02.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject02.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject02.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject02.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject02.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject03.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject03.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject03.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject03.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject03.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C8A1F10>
# title:	subject03.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject03.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject03.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject03.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject03.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject03.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject04.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject04.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject04.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject04.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject04.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x21339737E20>
# title:	subject04.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject04.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject04.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject04.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject04.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject04.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject05.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject05.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject05.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject05.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject05.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x213397B9B50>
# title:	subject05.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject05.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject05.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject05.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject05.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject05.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject06.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject06.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject06.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject06.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject06.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C8A1F10>
# title:	subject06.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject06.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject06.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject06.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject06.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject06.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject07.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject07.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject07.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject07.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject07.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x213397B9B50>
# title:	subject07.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject07.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject07.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject07.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject07.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject07.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject08.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject08.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject08.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject08.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject08.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x21339737E20>
# title:	subject08.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject08.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject08.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject08.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject08.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject08.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject09.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject09.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject09.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject09.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject09.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C8A1F10>
# title:	subject09.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject09.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject09.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject09.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject09.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject09.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject10.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject10.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject10.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject10.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject10.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x21339737E20>
# title:	subject10.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject10.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject10.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject10.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject10.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject10.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject11.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject11.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject11.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject11.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject11.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x213397B9B50>
# title:	subject11.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject11.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject11.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject11.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject11.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject11.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject12.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject12.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject12.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject12.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject12.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C8A1F10>
# title:	subject12.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject12.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject12.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject12.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject12.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject12.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject13.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject13.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject13.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject13.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject13.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x213397B9B50>
# title:	subject13.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject13.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject13.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject13.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject13.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject13.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject14.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject14.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject14.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject14.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject14.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x21339737E20>
# title:	subject14.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject14.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject14.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject14.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject14.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject14.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject15.centerlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject15.glasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject15.happy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject15.leftlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849B20>
# title:	subject15.noglasses		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C8A1F10>
# title:	subject15.normal		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject15.rightlight		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849940>
# title:	subject15.sad		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject15.sleepy		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>
# title:	subject15.surprised		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849AC0>
# title:	subject15.wink		<PIL.GifImagePlugin.GifImageFile image mode=L size=320x243 at 0x2133C849970>

# %%
#plotting 25 faces from these 165 images
img_data = []
path = 'data' #all images are in the folder named data
im = os.listdir(path)
for img in im:
    x = Image.open(os.path.join(path,img))
    img_data.append(x)

print(blue('Printing first 25 images',['bold', 'reverse']))
img_data1 = img_data[0:25]   
plt.figure(figsize=(8,6))
for i in range(len(img_data1)):
    plt.style.use('default')
    plt.subplot(5,5,i+1)
    plt.imshow(img_data1[i],cmap='Greys_r')
    #plt.savefig('q1.png')
    plt.axis('off')
# Out:
# Printing first 25 images
